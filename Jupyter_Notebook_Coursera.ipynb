# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Hupyter Notebook on IBM Watson Studo

# %% [markdown]
# Bold text: __Rahul__
# Student

# %% [markdown]
# Italic text: *I am interested in data science because it involve various ways of analysis and various observation skills which interest me.*

# %% [markdown]
# ### The following code is supposedd to print "Hello World".

# %%
print("Hello World")

# %% [markdown]
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# -  Point 1
# -  Point 2
# -  Point 3
#
# Col1 |Col2 |Col3
# -----|-----|-----
# Data1|Data2|Data3
# Data1|Data2|Data3
